# %% [markdown]
# <a href="https://colab.research.google.com/github/stinemcn/stinemcn/blob/main/Final_Project_Scraping2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the Telethon library for Telegram API interactions
# !pip install telethon
# Out:
# Collecting telethon
#   Downloading Telethon-1.38.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting pyaes (from telethon)
#   Downloading pyaes-1.6.1.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from telethon) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa->telethon) (0.6.1)
# Downloading Telethon-1.38.1-py3-none-any.whl (702 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.2/702.2 kB 11.6 MB/s eta 0:00:00
# Building wheels for collected packages: pyaes
#   Building wheel for pyaes (setup.py) ... done
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26346 sha256=088a85a8b32a1c3a51e38ab2077aa080b407e55e43808ee30d42379f7f853c56
#   Stored in directory: /root/.cache/pip/wheels/d6/84/5f/ea6aef85a93c7e1922486369874f4740a5642d261e09c59140
# Successfully built pyaes
# Installing collected packages: pyaes, telethon
# Successfully installed pyaes-1.6.1 telethon-1.38.1

# %%
# Setup / change every time to define scraping parameters
channels = [
    '@avrupagocveiltica',
]


d_min = 1  # Start day (inclusive)
m_min = 1  # Start month
y_min = 2024  # Start year
d_max = 1  # End day (exclusive)
m_max = 10  # End month
y_max = 2024  # End year
file_name = 'Test'  # Output file name
key_search = ''  # Keyword to search, leave empty if not needed
max_t_index = 1000000  # Maximum number of messages to scrape
time_limit = 6 * 60 * 60  # Timeout in hours (*seconds)
File = 'excel'  # Set to 'parquet' or 'excel'

# %%
# Initial imports
from datetime import datetime, timezone
import pandas as pd
import time
import json
import re

# Telegram imports
from telethon.sync import TelegramClient

# Google Colab imports
from google.colab import files

# Setup / change only the first time you use it
username = 'bobesttononcle'  # Your Telegram account username (just 'abc123', not '@')
phone = '+13023792736'  # Your Telegram account phone number (ex: '+5511999999999')
api_id = '22352213'  # Your API ID, it can be only generated from https://my.telegram.org/apps
api_hash = '22b3bdfdf9abe5b8001901069676f539'  # Your API hash, also from https://my.telegram.org/apps

# %%
data = []  # List to store scraped data
t_index = 0  # Tracker for the number of messages processed
start_time = time.time()  # Record the start time for the scraping session

# Function to remove invalid XML characters from text
def remove_unsupported_characters(text):
    valid_xml_chars = (
        "[^\u0009\u000A\u000D\u0020-\uD7FF\uE000-\uFFFD"
        "\U00010000-\U0010FFFF]"
    )
    cleaned_text = re.sub(valid_xml_chars, '', text)
    return cleaned_text

# Function to format time in days, hours, minutes, and seconds
def format_time(seconds):
    days = seconds // 86400
    hours = (seconds % 86400) // 3600
    minutes = (seconds % 3600) // 60
    seconds = seconds % 60
    return f'{int(days):02}:{int(hours):02}:{int(minutes):02}:{int(seconds):02}'

# Function to print progress of the scraping process
def print_progress(t_index, message_id, start_time, max_t_index):
    elapsed_time = time.time() - start_time
    current_progress = t_index / (t_index + message_id) if (t_index + message_id) <= max_t_index else t_index / max_t_index
    percentage = current_progress * 100
    estimated_total_time = elapsed_time / current_progress
    remaining_time = estimated_total_time - elapsed_time

    elapsed_time_str = format_time(elapsed_time)
    remaining_time_str = format_time(remaining_time)

    print(f'Progress: {percentage:.2f}% | Elapsed Time: {elapsed_time_str} | Remaining Time: {remaining_time_str}')

# Scraping process
for channel in channels:
    if t_index >= max_t_index:
        break

    if time.time() - start_time > time_limit:
        break

    loop_start_time = time.time()

    try:
        c_index = 0
        async with TelegramClient(username, api_id, api_hash) as client:
            async for message in client.iter_messages(channel, search=key_search):
                try:
                    if datetime(y_min, m_min, d_min, tzinfo=timezone.utc) < message.date <= datetime(y_max, m_max, d_max, tzinfo=timezone.utc):

                        # Process comments of the message
                        comments_list = []
                        try:
                            async for comment_message in client.iter_messages(channel, reply_to=message.id):
                                comment_text = comment_message.text.replace("'", '"')

                                comment_media = 'True' if comment_message.media else 'False'

                                comment_emoji_string = ''
                                if comment_message.reactions:
                                    for reaction_count in comment_message.reactions.results:
                                        emoji = reaction_count.reaction.emoticon
                                        count = str(reaction_count.count)
                                        comment_emoji_string += emoji + " " + count + " "

                                comment_date_time = comment_message.date.strftime('%Y-%m-%d %H:%M:%S')

                                comments_list.append({
                                    'Type': 'comment',
                                    'Comment Group': channel,
                                    'Comment Author ID': comment_message.sender_id,
                                    'Comment Content': comment_text,
                                    'Comment Date': comment_date_time,
                                    'Comment Message ID': comment_message.id,
                                    'Comment Author': comment_message.post_author,
                                    'Comment Views': comment_message.views,
                                    'Comment Reactions': comment_emoji_string,
                                    'Comment Shares': comment_message.forwards,
                                    'Comment Media': comment_media,
                                    'Comment Url': f'https://t.me/{channel}/{message.id}?comment={comment_message.id}'.replace('@', ''),
                                })
                        except Exception as e:
                            comments_list = []
                            print(f'Error processing comments: {e}')

                        # Process the main message
                        media = 'True' if message.media else 'False'

                        emoji_string = ''
                        if message.reactions:
                            for reaction_count in message.reactions.results:
                                emoji = reaction_count.reaction.emoticon
                                count = str(reaction_count.count)
                                emoji_string += emoji + " " + count + " "

                        date_time = message.date.strftime('%Y-%m-%d %H:%M:%S')
                        cleaned_content = remove_unsupported_characters(message.text)
                        cleaned_comments_list = remove_unsupported_characters(json.dumps(comments_list))

                        data.append({
                            'Type': 'text',
                            'Group': channel,
                            'Author ID': message.sender_id,
                            'Content': cleaned_content,
                            'Date': date_time,
                            'Message ID': message.id,
                            'Author': message.post_author,
                            'Views': message.views,
                            'Reactions': emoji_string,
                            'Shares': message.forwards,
                            'Media': media,
                            'Url': f'https://t.me/{channel}/{message.id}'.replace('@', ''),
                            'Comments List': cleaned_comments_list,
                        })

                        c_index += 1
                        t_index += 1

                        # Print progress
                        print(f'{"-" * 80}')
                        print_progress(t_index, message.id, start_time, max_t_index)
                        current_max_id = min(c_index + message.id, max_t_index)
                        print(f'From {channel}: {c_index:05} contents of {current_max_id:05}')
                        print(f'Id: {message.id:05} / Date: {date_time}')
                        print(f'Total: {t_index:05} contents until now')
                        print(f'{"-" * 80}\n\n')

                        if t_index % 1000 == 0:
                            if File == 'parquet':
                                backup_filename = f'backup_{file_name}_until_{t_index:05}_{channel}_ID{message.id:07}.parquet'
                                pd.DataFrame(data).to_parquet(backup_filename, index=False)
                            elif File == 'excel':
                                backup_filename = f'backup_{file_name}_until_{t_index:05}_{channel}_ID{message.id:07}.xlsx'
                                pd.DataFrame(data).to_excel(backup_filename, index=False)

                        if t_index >= max_t_index:
                            break

                        if time.time() - start_time > time_limit:
                            break

                    elif message.date < datetime(y_min, m_min, d_min, tzinfo=timezone.utc):
                        break

                except Exception as e:
                    print(f'Error processing message: {e}')

        print(f'\n\n##### {channel} was ok with {c_index:05} posts #####\n\n')

        df = pd.DataFrame(data)
        if File == 'parquet':
            partial_filename = f'complete_{channel}_in_{file_name}_until_{t_index:05}.parquet'
            df.to_parquet(partial_filename, index=False)
        elif File == 'excel':
            partial_filename = f'complete_{channel}_in_{file_name}_until_{t_index:05}.xlsx'
            df.to_excel(partial_filename, index=False)
        # files.download(partial_filename)

    except Exception as e:
        print(f'{channel} error: {e}')

    loop_end_time = time.time()
    loop_duration = loop_end_time - loop_start_time

    if loop_duration < 60:
        time.sleep(60 - loop_duration)

print(f'\n{"-" * 50}\n#Concluded! #{t_index:05} posts were scraped!\n{"-" * 50}\n\n\n\n')
df = pd.DataFrame(data)
if File == 'parquet':
    final_filename = f'FINAL_{file_name}_with_{t_index:05}.parquet'
    df.to_parquet(final_filename, index=False)
elif File == 'excel':
    final_filename = f'FINAL_{file_name}_with_{t_index:05}.xlsx'
    df.to_excel(final_filename, index=False)
files.download(final_filename)
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.12% | Elapsed Time: 00:00:22:02 | Remaining Time: 00:02:14:01
# From @avrupagocveiltica: 01600 contents of 11329
# Id: 09729 / Date: 2024-02-18 00:47:15
# Total: 01600 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.13% | Elapsed Time: 00:00:22:23 | Remaining Time: 00:02:16:06
# From @avrupagocveiltica: 01601 contents of 11329
# Id: 09728 / Date: 2024-02-18 00:37:50
# Total: 01601 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.14% | Elapsed Time: 00:00:22:24 | Remaining Time: 00:02:16:01
# From @avrupagocveiltica: 01602 contents of 11329
# Id: 09727 / Date: 2024-02-17 22:57:08
# Total: 01602 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.15% | Elapsed Time: 00:00:22:24 | Remaining Time: 00:02:15:57
# From @avrupagocveiltica: 01603 contents of 11329
# Id: 09726 / Date: 2024-02-17 22:48:19
# Total: 01603 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.16% | Elapsed Time: 00:00:22:24 | Remaining Time: 00:02:15:52
# From @avrupagocveiltica: 01604 contents of 11329
# Id: 09725 / Date: 2024-02-17 17:44:39
# Total: 01604 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.17% | Elapsed Time: 00:00:22:24 | Remaining Time: 00:02:15:48
# From @avrupagocveiltica: 01605 contents of 11329
# Id: 09724 / Date: 2024-02-17 17:44:31
# Total: 01605 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.18% | Elapsed Time: 00:00:22:25 | Remaining Time: 00:02:15:39
# From @avrupagocveiltica: 01606 contents of 11323
# Id: 09717 / Date: 2024-02-17 01:09:30
# Total: 01606 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.19% | Elapsed Time: 00:00:22:25 | Remaining Time: 00:02:15:34
# From @avrupagocveiltica: 01607 contents of 11323
# Id: 09716 / Date: 2024-02-16 23:09:14
# Total: 01607 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.20% | Elapsed Time: 00:00:22:26 | Remaining Time: 00:02:15:36
# From @avrupagocveiltica: 01608 contents of 11323
# Id: 09715 / Date: 2024-02-16 22:28:48
# Total: 01608 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.21% | Elapsed Time: 00:00:22:26 | Remaining Time: 00:02:15:32
# From @avrupagocveiltica: 01609 contents of 11323
# Id: 09714 / Date: 2024-02-16 21:43:17
# Total: 01609 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.22% | Elapsed Time: 00:00:22:27 | Remaining Time: 00:02:15:26
# From @avrupagocveiltica: 01610 contents of 11321
# Id: 09711 / Date: 2024-02-16 18:41:19
# Total: 01610 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.23% | Elapsed Time: 00:00:22:27 | Remaining Time: 00:02:15:21
# From @avrupagocveiltica: 01611 contents of 11321
# Id: 09710 / Date: 2024-02-16 18:40:32
# Total: 01611 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.24% | Elapsed Time: 00:00:22:27 | Remaining Time: 00:02:15:17
# From @avrupagocveiltica: 01612 contents of 11321
# Id: 09709 / Date: 2024-02-16 15:26:32
# Total: 01612 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.25% | Elapsed Time: 00:00:22:27 | Remaining Time: 00:02:15:12
# From @avrupagocveiltica: 01613 contents of 11321
# Id: 09708 / Date: 2024-02-16 15:26:32
# Total: 01613 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.26% | Elapsed Time: 00:00:22:28 | Remaining Time: 00:02:15:06
# From @avrupagocveiltica: 01614 contents of 11318
# Id: 09704 / Date: 2024-02-16 12:04:27
# Total: 01614 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.27% | Elapsed Time: 00:00:22:28 | Remaining Time: 00:02:15:01
# From @avrupagocveiltica: 01615 contents of 11318
# Id: 09703 / Date: 2024-02-16 12:04:04
# Total: 01615 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.28% | Elapsed Time: 00:00:22:28 | Remaining Time: 00:02:14:57
# From @avrupagocveiltica: 01616 contents of 11318
# Id: 09702 / Date: 2024-02-16 11:11:32
# Total: 01616 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.29% | Elapsed Time: 00:00:22:30 | Remaining Time: 00:02:14:59
# From @avrupagocveiltica: 01617 contents of 11318
# Id: 09701 / Date: 2024-02-16 11:10:12
# Total: 01617 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.30% | Elapsed Time: 00:00:22:30 | Remaining Time: 00:02:14:54
# From @avrupagocveiltica: 01618 contents of 11318
# Id: 09700 / Date: 2024-02-16 11:09:33
# Total: 01618 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.30% | Elapsed Time: 00:00:22:30 | Remaining Time: 00:02:14:50
# From @avrupagocveiltica: 01619 contents of 11318
# Id: 09699 / Date: 2024-02-16 11:09:23
# Total: 01619 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.31% | Elapsed Time: 00:00:22:30 | Remaining Time: 00:02:14:46
# From @avrupagocveiltica: 01620 contents of 11318
# Id: 09698 / Date: 2024-02-16 09:06:57
# Total: 01620 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.32% | Elapsed Time: 00:00:22:31 | Remaining Time: 00:02:14:42
# From @avrupagocveiltica: 01621 contents of 11318
# Id: 09697 / Date: 2024-02-16 09:06:49
# Total: 01621 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.33% | Elapsed Time: 00:00:22:32 | Remaining Time: 00:02:14:43
# From @avrupagocveiltica: 01622 contents of 11318
# Id: 09696 / Date: 2024-02-16 09:06:44
# Total: 01622 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.34% | Elapsed Time: 00:00:22:32 | Remaining Time: 00:02:14:38
# From @avrupagocveiltica: 01623 contents of 11317
# Id: 09694 / Date: 2024-02-16 05:45:09
# Total: 01623 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.35% | Elapsed Time: 00:00:22:34 | Remaining Time: 00:02:14:41
# From @avrupagocveiltica: 01624 contents of 11316
# Id: 09692 / Date: 2024-02-16 03:15:47
# Total: 01624 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.36% | Elapsed Time: 00:00:22:35 | Remaining Time: 00:02:14:43
# From @avrupagocveiltica: 01625 contents of 11316
# Id: 09691 / Date: 2024-02-16 03:10:12
# Total: 01625 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.37% | Elapsed Time: 00:00:22:35 | Remaining Time: 00:02:14:39
# From @avrupagocveiltica: 01626 contents of 11316
# Id: 09690 / Date: 2024-02-15 21:52:46
# Total: 01626 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.38% | Elapsed Time: 00:00:22:35 | Remaining Time: 00:02:14:34
# From @avrupagocveiltica: 01627 contents of 11316
# Id: 09689 / Date: 2024-02-15 21:49:51
# Total: 01627 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.39% | Elapsed Time: 00:00:22:36 | Remaining Time: 00:02:14:28
# From @avrupagocveiltica: 01628 contents of 11314
# Id: 09686 / Date: 2024-02-15 21:34:54
# Total: 01628 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.40% | Elapsed Time: 00:00:22:36 | Remaining Time: 00:02:14:24
# From @avrupagocveiltica: 01629 contents of 11314
# Id: 09685 / Date: 2024-02-15 21:34:36
# Total: 01629 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.41% | Elapsed Time: 00:00:22:36 | Remaining Time: 00:02:14:20
# From @avrupagocveiltica: 01630 contents of 11314
# Id: 09684 / Date: 2024-02-15 21:34:10
# Total: 01630 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.42% | Elapsed Time: 00:00:22:36 | Remaining Time: 00:02:14:15
# From @avrupagocveiltica: 01631 contents of 11314
# Id: 09683 / Date: 2024-02-15 21:34:06
# Total: 01631 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.42% | Elapsed Time: 00:00:22:37 | Remaining Time: 00:02:14:11
# From @avrupagocveiltica: 01632 contents of 11314
# Id: 09682 / Date: 2024-02-15 21:34:00
# Total: 01632 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.43% | Elapsed Time: 00:00:22:37 | Remaining Time: 00:02:14:07
# From @avrupagocveiltica: 01633 contents of 11314
# Id: 09681 / Date: 2024-02-15 21:33:59
# Total: 01633 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.44% | Elapsed Time: 00:00:22:37 | Remaining Time: 00:02:14:03
# From @avrupagocveiltica: 01634 contents of 11314
# Id: 09680 / Date: 2024-02-15 21:33:55
# Total: 01634 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.45% | Elapsed Time: 00:00:22:55 | Remaining Time: 00:02:15:41
# From @avrupagocveiltica: 01635 contents of 11314
# Id: 09679 / Date: 2024-02-15 21:33:52
# Total: 01635 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.46% | Elapsed Time: 00:00:22:55 | Remaining Time: 00:02:15:36
# From @avrupagocveiltica: 01636 contents of 11314
# Id: 09678 / Date: 2024-02-15 21:33:49
# Total: 01636 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.47% | Elapsed Time: 00:00:22:55 | Remaining Time: 00:02:15:32
# From @avrupagocveiltica: 01637 contents of 11314
# Id: 09677 / Date: 2024-02-15 21:33:43
# Total: 01637 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.48% | Elapsed Time: 00:00:22:55 | Remaining Time: 00:02:15:28
# From @avrupagocveiltica: 01638 contents of 11314
# Id: 09676 / Date: 2024-02-15 21:33:36
# Total: 01638 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.49% | Elapsed Time: 00:00:22:56 | Remaining Time: 00:02:15:23
# From @avrupagocveiltica: 01639 contents of 11314
# Id: 09675 / Date: 2024-02-15 21:33:28
# Total: 01639 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.50% | Elapsed Time: 00:00:22:56 | Remaining Time: 00:02:15:19
# From @avrupagocveiltica: 01640 contents of 11314
# Id: 09674 / Date: 2024-02-15 21:33:16
# Total: 01640 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.50% | Elapsed Time: 00:00:22:56 | Remaining Time: 00:02:15:15
# From @avrupagocveiltica: 01641 contents of 11314
# Id: 09673 / Date: 2024-02-15 21:33:15
# Total: 01641 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.51% | Elapsed Time: 00:00:22:56 | Remaining Time: 00:02:15:11
# From @avrupagocveiltica: 01642 contents of 11314
# Id: 09672 / Date: 2024-02-15 21:33:04
# Total: 01642 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.52% | Elapsed Time: 00:00:22:57 | Remaining Time: 00:02:15:06
# From @avrupagocveiltica: 01643 contents of 11314
# Id: 09671 / Date: 2024-02-15 21:32:49
# Total: 01643 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.53% | Elapsed Time: 00:00:22:57 | Remaining Time: 00:02:15:02
# From @avrupagocveiltica: 01644 contents of 11314
# Id: 09670 / Date: 2024-02-15 21:32:49
# Total: 01644 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.54% | Elapsed Time: 00:00:22:57 | Remaining Time: 00:02:14:59
# From @avrupagocveiltica: 01645 contents of 11314
# Id: 09669 / Date: 2024-02-15 21:32:43
# Total: 01645 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.55% | Elapsed Time: 00:00:22:58 | Remaining Time: 00:02:14:55
# From @avrupagocveiltica: 01646 contents of 11314
# Id: 09668 / Date: 2024-02-15 21:32:24
# Total: 01646 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.56% | Elapsed Time: 00:00:22:58 | Remaining Time: 00:02:14:50
# From @avrupagocveiltica: 01647 contents of 11314
# Id: 09667 / Date: 2024-02-15 21:32:21
# Total: 01647 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.57% | Elapsed Time: 00:00:22:58 | Remaining Time: 00:02:14:46
# From @avrupagocveiltica: 01648 contents of 11314
# Id: 09666 / Date: 2024-02-15 21:32:14
# Total: 01648 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.57% | Elapsed Time: 00:00:22:58 | Remaining Time: 00:02:14:42
# From @avrupagocveiltica: 01649 contents of 11314
# Id: 09665 / Date: 2024-02-15 21:31:31
# Total: 01649 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.58% | Elapsed Time: 00:00:22:59 | Remaining Time: 00:02:14:38
# From @avrupagocveiltica: 01650 contents of 11314
# Id: 09664 / Date: 2024-02-15 21:31:19
# Total: 01650 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.59% | Elapsed Time: 00:00:22:59 | Remaining Time: 00:02:14:33
# From @avrupagocveiltica: 01651 contents of 11314
# Id: 09663 / Date: 2024-02-15 21:30:43
# Total: 01651 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.60% | Elapsed Time: 00:00:22:59 | Remaining Time: 00:02:14:29
# From @avrupagocveiltica: 01652 contents of 11314
# Id: 09662 / Date: 2024-02-15 21:30:09
# Total: 01652 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.61% | Elapsed Time: 00:00:23:00 | Remaining Time: 00:02:14:31
# From @avrupagocveiltica: 01653 contents of 11314
# Id: 09661 / Date: 2024-02-15 21:29:38
# Total: 01653 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.62% | Elapsed Time: 00:00:23:01 | Remaining Time: 00:02:14:26
# From @avrupagocveiltica: 01654 contents of 11314
# Id: 09660 / Date: 2024-02-15 21:23:40
# Total: 01654 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.63% | Elapsed Time: 00:00:23:02 | Remaining Time: 00:02:14:28
# From @avrupagocveiltica: 01655 contents of 11314
# Id: 09659 / Date: 2024-02-15 20:46:08
# Total: 01655 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.64% | Elapsed Time: 00:00:23:02 | Remaining Time: 00:02:14:19
# From @avrupagocveiltica: 01656 contents of 11308
# Id: 09652 / Date: 2024-02-14 20:32:38
# Total: 01656 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.66% | Elapsed Time: 00:00:23:02 | Remaining Time: 00:02:14:10
# From @avrupagocveiltica: 01657 contents of 11303
# Id: 09646 / Date: 2024-02-14 15:30:04
# Total: 01657 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.67% | Elapsed Time: 00:00:23:03 | Remaining Time: 00:02:14:06
# From @avrupagocveiltica: 01658 contents of 11303
# Id: 09645 / Date: 2024-02-14 07:46:58
# Total: 01658 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.68% | Elapsed Time: 00:00:23:03 | Remaining Time: 00:02:14:01
# From @avrupagocveiltica: 01659 contents of 11302
# Id: 09643 / Date: 2024-02-13 21:36:04
# Total: 01659 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.69% | Elapsed Time: 00:00:23:03 | Remaining Time: 00:02:13:57
# From @avrupagocveiltica: 01660 contents of 11302
# Id: 09642 / Date: 2024-02-13 21:24:04
# Total: 01660 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.70% | Elapsed Time: 00:00:23:03 | Remaining Time: 00:02:13:52
# From @avrupagocveiltica: 01661 contents of 11301
# Id: 09640 / Date: 2024-02-13 17:50:55
# Total: 01661 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.71% | Elapsed Time: 00:00:23:04 | Remaining Time: 00:02:13:48
# From @avrupagocveiltica: 01662 contents of 11301
# Id: 09639 / Date: 2024-02-13 17:50:18
# Total: 01662 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.72% | Elapsed Time: 00:00:23:04 | Remaining Time: 00:02:13:43
# From @avrupagocveiltica: 01663 contents of 11301
# Id: 09638 / Date: 2024-02-13 14:51:49
# Total: 01663 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.73% | Elapsed Time: 00:00:23:04 | Remaining Time: 00:02:13:33
# From @avrupagocveiltica: 01664 contents of 11294
# Id: 09630 / Date: 2024-02-12 18:09:23
# Total: 01664 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.74% | Elapsed Time: 00:00:23:04 | Remaining Time: 00:02:13:29
# From @avrupagocveiltica: 01665 contents of 11294
# Id: 09629 / Date: 2024-02-12 17:01:57
# Total: 01665 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.75% | Elapsed Time: 00:00:23:05 | Remaining Time: 00:02:13:25
# From @avrupagocveiltica: 01666 contents of 11294
# Id: 09628 / Date: 2024-02-12 17:01:21
# Total: 01666 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.76% | Elapsed Time: 00:00:23:26 | Remaining Time: 00:02:15:21
# From @avrupagocveiltica: 01667 contents of 11291
# Id: 09624 / Date: 2024-02-12 15:01:22
# Total: 01667 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.77% | Elapsed Time: 00:00:23:26 | Remaining Time: 00:02:15:17
# From @avrupagocveiltica: 01668 contents of 11291
# Id: 09623 / Date: 2024-02-12 13:49:56
# Total: 01668 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.78% | Elapsed Time: 00:00:23:27 | Remaining Time: 00:02:15:12
# From @avrupagocveiltica: 01669 contents of 11290
# Id: 09621 / Date: 2024-02-12 12:54:04
# Total: 01669 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.79% | Elapsed Time: 00:00:23:27 | Remaining Time: 00:02:15:06
# From @avrupagocveiltica: 01670 contents of 11288
# Id: 09618 / Date: 2024-02-12 12:52:56
# Total: 01670 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.80% | Elapsed Time: 00:00:23:27 | Remaining Time: 00:02:15:01
# From @avrupagocveiltica: 01671 contents of 11288
# Id: 09617 / Date: 2024-02-12 12:52:25
# Total: 01671 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.81% | Elapsed Time: 00:00:23:27 | Remaining Time: 00:02:14:57
# From @avrupagocveiltica: 01672 contents of 11288
# Id: 09616 / Date: 2024-02-12 12:51:43
# Total: 01672 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.82% | Elapsed Time: 00:00:23:28 | Remaining Time: 00:02:14:52
# From @avrupagocveiltica: 01673 contents of 11287
# Id: 09614 / Date: 2024-02-12 12:51:09
# Total: 01673 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.83% | Elapsed Time: 00:00:23:28 | Remaining Time: 00:02:14:47
# From @avrupagocveiltica: 01674 contents of 11286
# Id: 09612 / Date: 2024-02-12 12:50:15
# Total: 01674 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.84% | Elapsed Time: 00:00:23:28 | Remaining Time: 00:02:14:41
# From @avrupagocveiltica: 01675 contents of 11284
# Id: 09609 / Date: 2024-02-12 12:49:09
# Total: 01675 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.86% | Elapsed Time: 00:00:23:29 | Remaining Time: 00:02:14:40
# From @avrupagocveiltica: 01676 contents of 11281
# Id: 09605 / Date: 2024-02-11 21:17:53
# Total: 01676 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.87% | Elapsed Time: 00:00:23:31 | Remaining Time: 00:02:14:41
# From @avrupagocveiltica: 01677 contents of 11280
# Id: 09603 / Date: 2024-02-10 21:27:05
# Total: 01677 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.88% | Elapsed Time: 00:00:23:31 | Remaining Time: 00:02:14:36
# From @avrupagocveiltica: 01678 contents of 11280
# Id: 09602 / Date: 2024-02-10 19:37:32
# Total: 01678 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.88% | Elapsed Time: 00:00:23:31 | Remaining Time: 00:02:14:32
# From @avrupagocveiltica: 01679 contents of 11280
# Id: 09601 / Date: 2024-02-10 18:14:25
# Total: 01679 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.89% | Elapsed Time: 00:00:23:31 | Remaining Time: 00:02:14:28
# From @avrupagocveiltica: 01680 contents of 11280
# Id: 09600 / Date: 2024-02-09 23:33:41
# Total: 01680 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.90% | Elapsed Time: 00:00:23:33 | Remaining Time: 00:02:14:29
# From @avrupagocveiltica: 01681 contents of 11280
# Id: 09599 / Date: 2024-02-09 22:12:28
# Total: 01681 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.91% | Elapsed Time: 00:00:23:33 | Remaining Time: 00:02:14:25
# From @avrupagocveiltica: 01682 contents of 11280
# Id: 09598 / Date: 2024-02-09 22:04:42
# Total: 01682 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.92% | Elapsed Time: 00:00:23:33 | Remaining Time: 00:02:14:21
# From @avrupagocveiltica: 01683 contents of 11280
# Id: 09597 / Date: 2024-02-09 22:04:14
# Total: 01683 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.93% | Elapsed Time: 00:00:23:34 | Remaining Time: 00:02:14:17
# From @avrupagocveiltica: 01684 contents of 11280
# Id: 09596 / Date: 2024-02-09 22:03:39
# Total: 01684 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.94% | Elapsed Time: 00:00:23:34 | Remaining Time: 00:02:14:13
# From @avrupagocveiltica: 01685 contents of 11280
# Id: 09595 / Date: 2024-02-09 22:02:27
# Total: 01685 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.95% | Elapsed Time: 00:00:23:34 | Remaining Time: 00:02:14:09
# From @avrupagocveiltica: 01686 contents of 11280
# Id: 09594 / Date: 2024-02-09 20:49:32
# Total: 01686 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.96% | Elapsed Time: 00:00:23:34 | Remaining Time: 00:02:14:05
# From @avrupagocveiltica: 01687 contents of 11280
# Id: 09593 / Date: 2024-02-09 20:34:07
# Total: 01687 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.96% | Elapsed Time: 00:00:23:35 | Remaining Time: 00:02:14:00
# From @avrupagocveiltica: 01688 contents of 11280
# Id: 09592 / Date: 2024-02-09 20:33:53
# Total: 01688 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.97% | Elapsed Time: 00:00:23:35 | Remaining Time: 00:02:13:56
# From @avrupagocveiltica: 01689 contents of 11280
# Id: 09591 / Date: 2024-02-09 14:09:46
# Total: 01689 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 14.98% | Elapsed Time: 00:00:23:35 | Remaining Time: 00:02:13:52
# From @avrupagocveiltica: 01690 contents of 11280
# Id: 09590 / Date: 2024-02-09 14:07:55
# Total: 01690 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 14.99% | Elapsed Time: 00:00:23:35 | Remaining Time: 00:02:13:48
# From @avrupagocveiltica: 01691 contents of 11280
# Id: 09589 / Date: 2024-02-09 13:27:41
# Total: 01691 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.00% | Elapsed Time: 00:00:23:36 | Remaining Time: 00:02:13:44
# From @avrupagocveiltica: 01692 contents of 11280
# Id: 09588 / Date: 2024-02-09 13:00:58
# Total: 01692 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 15.01% | Elapsed Time: 00:00:23:36 | Remaining Time: 00:02:13:39
# From @avrupagocveiltica: 01693 contents of 11280
# Id: 09587 / Date: 2024-02-09 13:00:26
# Total: 01693 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 15.02% | Elapsed Time: 00:00:23:36 | Remaining Time: 00:02:13:35
# From @avrupagocveiltica: 01694 contents of 11280
# Id: 09586 / Date: 2024-02-09 13:00:17
# Total: 01694 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.03% | Elapsed Time: 00:00:23:37 | Remaining Time: 00:02:13:37
# From @avrupagocveiltica: 01695 contents of 11280
# Id: 09585 / Date: 2024-02-09 12:40:50
# Total: 01695 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.04% | Elapsed Time: 00:00:23:38 | Remaining Time: 00:02:13:32
# From @avrupagocveiltica: 01696 contents of 11279
# Id: 09583 / Date: 2024-02-09 10:18:24
# Total: 01696 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 15.05% | Elapsed Time: 00:00:23:38 | Remaining Time: 00:02:13:28
# From @avrupagocveiltica: 01697 contents of 11279
# Id: 09582 / Date: 2024-02-09 09:01:04
# Total: 01697 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 15.05% | Elapsed Time: 00:00:23:38 | Remaining Time: 00:02:13:24
# From @avrupagocveiltica: 01698 contents of 11279
# Id: 09581 / Date: 2024-02-09 08:08:27
# Total: 01698 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.06% | Elapsed Time: 00:00:23:38 | Remaining Time: 00:02:13:19
# From @avrupagocveiltica: 01699 contents of 11279
# Id: 09580 / Date: 2024-02-09 07:48:08
# Total: 01699 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.07% | Elapsed Time: 00:00:23:39 | Remaining Time: 00:02:13:15
# From @avrupagocveiltica: 01700 contents of 11279
# Id: 09579 / Date: 2024-02-09 07:48:07
# Total: 01700 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 15.08% | Elapsed Time: 00:00:23:39 | Remaining Time: 00:02:13:11
# From @avrupagocveiltica: 01701 contents of 11279
# Id: 09578 / Date: 2024-02-09 05:03:52
# Total: 01701 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.09% | Elapsed Time: 00:00:23:40 | Remaining Time: 00:02:13:13
# From @avrupagocveiltica: 01702 contents of 11279
# Id: 09577 / Date: 2024-02-09 00:10:02
# Total: 01702 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.10% | Elapsed Time: 00:00:23:40 | Remaining Time: 00:02:13:09
# From @avrupagocveiltica: 01703 contents of 11279
# Id: 09576 / Date: 2024-02-09 00:09:46
# Total: 01703 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.11% | Elapsed Time: 00:00:23:58 | Remaining Time: 00:02:14:42
# From @avrupagocveiltica: 01704 contents of 11279
# Id: 09575 / Date: 2024-02-09 00:09:42
# Total: 01704 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.12% | Elapsed Time: 00:00:23:58 | Remaining Time: 00:02:14:37
# From @avrupagocveiltica: 01705 contents of 11277
# Id: 09572 / Date: 2024-02-08 22:50:17
# Total: 01705 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.13% | Elapsed Time: 00:00:23:59 | Remaining Time: 00:02:14:33
# From @avrupagocveiltica: 01706 contents of 11277
# Id: 09571 / Date: 2024-02-08 22:49:38
# Total: 01706 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.14% | Elapsed Time: 00:00:23:59 | Remaining Time: 00:02:14:29
# From @avrupagocveiltica: 01707 contents of 11277
# Id: 09570 / Date: 2024-02-08 22:44:09
# Total: 01707 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.15% | Elapsed Time: 00:00:23:59 | Remaining Time: 00:02:14:24
# From @avrupagocveiltica: 01708 contents of 11276
# Id: 09568 / Date: 2024-01-23 09:21:24
# Total: 01708 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: expected string or bytes-like object
# --------------------------------------------------------------------------------
# Progress: 15.17% | Elapsed Time: 00:00:24:00 | Remaining Time: 00:02:14:11
# From @avrupagocveiltica: 01709 contents of 11264
# Id: 09555 / Date: 2024-01-22 18:22:11
# Total: 01709 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 15.18% | Elapsed Time: 00:00:24:00 | Remaining Time: 00:02:14:06
# From @avrupagocveiltica: 01710 contents of 11264
# Id: 09554 / Date: 2024-01-22 18:21:56
# Total: 01710 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.19% | Elapsed Time: 00:00:24:01 | Remaining Time: 00:02:14:07
# From @avrupagocveiltica: 01711 contents of 11263
# Id: 09552 / Date: 2024-01-22 17:24:03
# Total: 01711 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.20% | Elapsed Time: 00:00:24:01 | Remaining Time: 00:02:14:01
# From @avrupagocveiltica: 01712 contents of 11261
# Id: 09549 / Date: 2024-01-22 16:51:46
# Total: 01712 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.24% | Elapsed Time: 00:00:24:02 | Remaining Time: 00:02:13:39
# From @avrupagocveiltica: 01713 contents of 11239
# Id: 09526 / Date: 2024-01-22 14:47:53
# Total: 01713 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.25% | Elapsed Time: 00:00:24:02 | Remaining Time: 00:02:13:34
# From @avrupagocveiltica: 01714 contents of 11239
# Id: 09525 / Date: 2024-01-22 12:24:44
# Total: 01714 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.26% | Elapsed Time: 00:00:24:02 | Remaining Time: 00:02:13:30
# From @avrupagocveiltica: 01715 contents of 11239
# Id: 09524 / Date: 2024-01-22 12:13:04
# Total: 01715 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.27% | Elapsed Time: 00:00:24:02 | Remaining Time: 00:02:13:26
# From @avrupagocveiltica: 01716 contents of 11239
# Id: 09523 / Date: 2024-01-22 12:09:21
# Total: 01716 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 15.28% | Elapsed Time: 00:00:24:03 | Remaining Time: 00:02:13:21
# From @avrupagocveiltica: 01717 contents of 11238
# Id: 09521 / Date: 2024-01-22 11:35:24
# Total: 01717 contents until now
# ...
# From @avrupagocveiltica: 02163 contents of 10141
# Id: 07978 / Date: 2024-01-03 23:20:02
# Total: 02163 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.34% | Elapsed Time: 00:00:30:14 | Remaining Time: 00:01:51:27
# From @avrupagocveiltica: 02164 contents of 10141
# Id: 07977 / Date: 2024-01-03 21:01:58
# Total: 02164 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.35% | Elapsed Time: 00:00:30:14 | Remaining Time: 00:01:51:24
# From @avrupagocveiltica: 02165 contents of 10140
# Id: 07975 / Date: 2024-01-03 19:09:57
# Total: 02165 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.36% | Elapsed Time: 00:00:30:14 | Remaining Time: 00:01:51:21
# From @avrupagocveiltica: 02166 contents of 10140
# Id: 07974 / Date: 2024-01-03 19:07:12
# Total: 02166 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.37% | Elapsed Time: 00:00:30:15 | Remaining Time: 00:01:51:18
# From @avrupagocveiltica: 02167 contents of 10140
# Id: 07973 / Date: 2024-01-03 19:04:44
# Total: 02167 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.38% | Elapsed Time: 00:00:30:15 | Remaining Time: 00:01:51:15
# From @avrupagocveiltica: 02168 contents of 10140
# Id: 07972 / Date: 2024-01-03 18:58:17
# Total: 02168 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.39% | Elapsed Time: 00:00:30:15 | Remaining Time: 00:01:51:11
# From @avrupagocveiltica: 02169 contents of 10139
# Id: 07970 / Date: 2024-01-03 18:40:33
# Total: 02169 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.40% | Elapsed Time: 00:00:30:16 | Remaining Time: 00:01:51:12
# From @avrupagocveiltica: 02170 contents of 10139
# Id: 07969 / Date: 2024-01-03 18:38:57
# Total: 02170 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.41% | Elapsed Time: 00:00:30:17 | Remaining Time: 00:01:51:09
# From @avrupagocveiltica: 02171 contents of 10139
# Id: 07968 / Date: 2024-01-03 18:37:34
# Total: 02171 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.42% | Elapsed Time: 00:00:30:17 | Remaining Time: 00:01:51:06
# From @avrupagocveiltica: 02172 contents of 10139
# Id: 07967 / Date: 2024-01-03 18:36:39
# Total: 02172 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.43% | Elapsed Time: 00:00:30:17 | Remaining Time: 00:01:51:03
# From @avrupagocveiltica: 02173 contents of 10139
# Id: 07966 / Date: 2024-01-03 18:36:25
# Total: 02173 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.44% | Elapsed Time: 00:00:30:17 | Remaining Time: 00:01:50:59
# From @avrupagocveiltica: 02174 contents of 10138
# Id: 07964 / Date: 2024-01-03 17:15:58
# Total: 02174 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.45% | Elapsed Time: 00:00:30:19 | Remaining Time: 00:01:50:59
# From @avrupagocveiltica: 02175 contents of 10138
# Id: 07963 / Date: 2024-01-03 17:01:19
# Total: 02175 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.46% | Elapsed Time: 00:00:30:19 | Remaining Time: 00:01:50:56
# From @avrupagocveiltica: 02176 contents of 10138
# Id: 07962 / Date: 2024-01-03 16:59:37
# Total: 02176 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.47% | Elapsed Time: 00:00:30:19 | Remaining Time: 00:01:50:53
# From @avrupagocveiltica: 02177 contents of 10138
# Id: 07961 / Date: 2024-01-03 16:00:05
# Total: 02177 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.49% | Elapsed Time: 00:00:30:20 | Remaining Time: 00:01:50:52
# From @avrupagocveiltica: 02178 contents of 10136
# Id: 07958 / Date: 2024-01-03 15:53:20
# Total: 02178 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.50% | Elapsed Time: 00:00:30:21 | Remaining Time: 00:01:50:49
# From @avrupagocveiltica: 02179 contents of 10135
# Id: 07956 / Date: 2024-01-03 14:30:16
# Total: 02179 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.51% | Elapsed Time: 00:00:30:21 | Remaining Time: 00:01:50:46
# From @avrupagocveiltica: 02180 contents of 10135
# Id: 07955 / Date: 2024-01-03 14:29:56
# Total: 02180 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.52% | Elapsed Time: 00:00:30:21 | Remaining Time: 00:01:50:43
# From @avrupagocveiltica: 02181 contents of 10135
# Id: 07954 / Date: 2024-01-03 14:29:50
# Total: 02181 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.53% | Elapsed Time: 00:00:30:21 | Remaining Time: 00:01:50:38
# From @avrupagocveiltica: 02182 contents of 10133
# Id: 07951 / Date: 2024-01-03 14:29:07
# Total: 02182 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.54% | Elapsed Time: 00:00:30:22 | Remaining Time: 00:01:50:36
# From @avrupagocveiltica: 02183 contents of 10133
# Id: 07950 / Date: 2024-01-03 14:28:51
# Total: 02183 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.56% | Elapsed Time: 00:00:30:22 | Remaining Time: 00:01:50:32
# From @avrupagocveiltica: 02184 contents of 10132
# Id: 07948 / Date: 2024-01-03 14:23:57
# Total: 02184 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.57% | Elapsed Time: 00:00:30:22 | Remaining Time: 00:01:50:29
# From @avrupagocveiltica: 02185 contents of 10132
# Id: 07947 / Date: 2024-01-03 14:23:46
# Total: 02185 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.58% | Elapsed Time: 00:00:30:22 | Remaining Time: 00:01:50:24
# From @avrupagocveiltica: 02186 contents of 10130
# Id: 07944 / Date: 2024-01-03 08:02:05
# Total: 02186 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.59% | Elapsed Time: 00:00:30:23 | Remaining Time: 00:01:50:21
# From @avrupagocveiltica: 02187 contents of 10130
# Id: 07943 / Date: 2024-01-03 00:48:14
# Total: 02187 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.60% | Elapsed Time: 00:00:30:23 | Remaining Time: 00:01:50:18
# From @avrupagocveiltica: 02188 contents of 10130
# Id: 07942 / Date: 2024-01-03 00:42:45
# Total: 02188 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.61% | Elapsed Time: 00:00:30:24 | Remaining Time: 00:01:50:19
# From @avrupagocveiltica: 02189 contents of 10130
# Id: 07941 / Date: 2024-01-02 21:38:23
# Total: 02189 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.62% | Elapsed Time: 00:00:30:24 | Remaining Time: 00:01:50:16
# From @avrupagocveiltica: 02190 contents of 10130
# Id: 07940 / Date: 2024-01-02 21:38:06
# Total: 02190 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.63% | Elapsed Time: 00:00:30:25 | Remaining Time: 00:01:50:13
# From @avrupagocveiltica: 02191 contents of 10130
# Id: 07939 / Date: 2024-01-02 19:41:47
# Total: 02191 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.64% | Elapsed Time: 00:00:30:25 | Remaining Time: 00:01:50:09
# From @avrupagocveiltica: 02192 contents of 10129
# Id: 07937 / Date: 2024-01-02 19:21:36
# Total: 02192 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.65% | Elapsed Time: 00:00:30:25 | Remaining Time: 00:01:50:06
# From @avrupagocveiltica: 02193 contents of 10129
# Id: 07936 / Date: 2024-01-02 19:18:25
# Total: 02193 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: An invalid Peer was used. Make sure to pass the right peer type and that the value is valid (for instance, bots cannot start conversations) (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 21.66% | Elapsed Time: 00:00:30:25 | Remaining Time: 00:01:50:03
# From @avrupagocveiltica: 02194 contents of 10129
# Id: 07935 / Date: 2024-01-02 19:18:21
# Total: 02194 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.67% | Elapsed Time: 00:00:30:27 | Remaining Time: 00:01:50:04
# From @avrupagocveiltica: 02195 contents of 10129
# Id: 07934 / Date: 2024-01-02 19:16:19
# Total: 02195 contents until now
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Progress: 21.69% | Elapsed Time: 00:00:30:27 | Remaining Time: 00:01:49:59
# From @avrupagocveiltica: 02196 contents of 10126
# Id: 07930 / Date: 2024-01-02 19:12:55
# Total: 02196 contents until now
# --------------------------------------------------------------------------------
#
#
#
#
# ##### @avrupagocveiltica was ok with 02196 posts #####
#
#
#
# --------------------------------------------------
# #Concluded! #02196 posts were scraped!
# --------------------------------------------------
